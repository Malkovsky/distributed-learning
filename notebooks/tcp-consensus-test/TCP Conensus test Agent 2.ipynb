# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import asyncio

import os
import sys
module_path = os.path.abspath('../..')
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from utils.consensus_tcp import ConsensusMaster, ConsensusAgent

# %%
agent = ConsensusAgent(2, '127.0.0.1', 9002, '127.0.0.1', 9000, convergence_eps=1e-3, debug=True)

# %%
agent_serve_task = asyncio.create_task(agent.serve_forever())
# Out:
# Serving on ('127.0.0.1', 9002)
# Agent "2": Serving...

# %%
await agent.run_round(np.array([0., 1., 0.]), 1)
# Out:
# Agent "2": Performing handshake with master
# Agent "2": Successfully registered. Waiting for neighborhood data...
# Agent "2": From: ('127.0.0.1', 49758). Registered 1!
# Agent "2": Got neighborhood data. Waiting for consensus epsilon...
# Agent "2": Got consensus epsilon!
# Agent "2": Performing handshake with neighbors...
# Agent "2": Performing handshake with 1
# Agent "2": From: ('127.0.0.1', 49760). Registered 3!
# Agent "2": Success!
# Agent "2": Performing handshake with 3
# Agent "2": Success!
# Agent "2": We are ready for consensus now!
# Agent "2": running new round with v=[0. 1. 0.], w=1
# Agent "2": sending new round request to master
# Agent "2": waiting for new round notification from master
# Agent "2": Got new round notification from master! Round id: 1
# Agent "2": Adding value to history with key (1, 0)
# Agent "2": requesting value from agent(1) - (1, 0)
# Agent "2": requesting value from agent(3) - (1, 0)
# Agent "2": Got value request from agent(1) for (1, 0)
# ...

# %%
await agent.run_round(np.array([0., 10., 0.]), 2)
# Out:
# Agent "2": running new round with v=[ 0. 10.  0.], w=2
# Agent "2": sending new round request to master
# Agent "2": waiting for new round notification from master
# Agent "2": Got new round notification from master! Round id: 2
# Agent "2": Adding value to history with key (2, 0)
# Agent "2": requesting value from agent(1) - (2, 0)
# Agent "2": requesting value from agent(3) - (2, 0)
# Agent "2": ! got request/response from "3" from previous round/iteration: (1, 11)
# Agent "2": Got value request from agent(3) for (2, 0)
# Agent "2": Got value request from agent(1) for (2, 0)
# Agent "2": All neighbors got our value for (2, 0)! Deleting it
# Agent "2": got value from "1"!
# Agent "2": got value from "3"!
# Agent "2": finished iteration #0
# Agent "2": Adding value to history with key (2, 1)
# Agent "2": requesting value from agent(1) - (2, 1)
# Agent "2": requesting value from agent(3) - (2, 1)
# Agent "2": Got value request from agent(1) for (2, 1)
# ...
