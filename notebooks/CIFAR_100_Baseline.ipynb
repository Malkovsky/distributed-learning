# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1avq4ar_Jw1pwELib8Uj_jafob7rDt3wf)

# %%
! pip install torchvision
! git clone https://github.com/meliketoy/wide-resnet.pytorch
# Out:
# ...
# Cloning into 'wide-resnet.pytorch'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 124 (delta 4), reused 11 (delta 3), pack-reused 111
# Receiving objects: 100% (124/124), 674.93 KiB | 20.45 MiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
import torch
print(torch.cuda.is_available())
print(torch.version.cuda)
print(torch.__version__)
assert(torch.cuda.is_available())
# Out:
# True
# 10.1
# 1.7.0+cu101

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Set number of epochs to 100

# %%
# !sed -i "s/num_epochs\s=\s200/num_epochs = 100/g" wide-resnet.pytorch/config.py

# %% [markdown]
# Set checkpoint path to Google.Drive

# %%
# !sed -i "s/dir('checkpoint')/dir('drive\/My\ Drive\/checkpoint')/g" wide-resnet.pytorch/main.py
# !sed -i "s/save_point\s=\s'\.\/checkpoint/save_point = '.\/drive\/My\ Drive\/checkpoint/g" wide-resnet.pytorch/main.py
# !sed -i "s/torch\.load('\.\/checkpoint/torch\.load\('.\/drive\/My\ Drive\/checkpoint/g" wide-resnet.pytorch/main.py
! mkdir -p drive/My\ Drive/checkpoint

# %%
# !nvidia-smi
# Out:
# Tue Nov 10 10:06:01 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.32.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    27W / 250W |     10MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
! python wide-resnet.pytorch/main.py --lr 0.1 --net_type wide-resnet --depth 28 --widen_factor 10 --dropout 0.3 --dataset cifar100
# Out:
# [Phase 1] : Data Preparation
# | Preparing CIFAR-100 dataset...
# | Files already downloaded and verified
#
# [Phase 2] : Model setup
# | Building net type [wide-resnet]...
# | Wide-Resnet 28x10
#
# [Phase 3] : Training model
# | Training Epochs = 100
# | Initial Learning Rate = 0.1
# | Optimizer = SGD
#
# => Training Epoch #1, LR=0.1000
# | Epoch [  1/100] Iter[391/391]		Loss: 3.2183 Acc@1: 9.384%
# | Validation Epoch #1			Loss: 3.7784 Acc@1: 11.33%
# | Saving Best model...			Top1 = 11.33%
# | Elapsed time : 0:02:35
#
# => Training Epoch #2, LR=0.1000
# | Epoch [  2/100] Iter[391/391]		Loss: 3.0579 Acc@1: 19.750%
# | Validation Epoch #2			Loss: 3.1542 Acc@1: 22.60%
# | Saving Best model...			Top1 = 22.60%
# | Elapsed time : 0:05:06
#
# => Training Epoch #3, LR=0.1000
# | Epoch [  3/100] Iter[391/391]		Loss: 2.8248 Acc@1: 28.884%
# | Validation Epoch #3			Loss: 2.7312 Acc@1: 30.03%
# | Saving Best model...			Top1 = 30.03%
# | Elapsed time : 0:07:38
#
# ...
